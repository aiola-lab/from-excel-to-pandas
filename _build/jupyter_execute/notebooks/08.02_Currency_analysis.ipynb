# %% [markdown]
# # Currency Rate Analysis

# %% [markdown]
# > Money often costs too much. --Ralph Waldo Emerson
#
# A very used expression in our life, and if utilized just right, also very useful.
#
# In this notebook, we query a REST API to get the latest currency rates for many currencies. Using dynamic API compared to loading static files allows for updated data to be processed.

# %% [markdown]
# ## Loading data using API
#
# First of all, let's get our data.
#
# In order to do so, let's start with installing all the needed libraries and get the right imports.

# %%
pip install forex-python
# Out:
# Requirement already satisfied: forex-python in /Users/guy/miniconda3/lib/python3.8/site-packages (1.5)
# Requirement already satisfied: requests in /Users/guy/miniconda3/lib/python3.8/site-packages (from forex-python) (2.23.0)
# Requirement already satisfied: simplejson in /Users/guy/miniconda3/lib/python3.8/site-packages (from forex-python) (3.17.2)
# Requirement already satisfied: idna<3,>=2.5 in /Users/guy/miniconda3/lib/python3.8/site-packages (from requests->forex-python) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/guy/miniconda3/lib/python3.8/site-packages (from requests->forex-python) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/guy/miniconda3/lib/python3.8/site-packages (from requests->forex-python) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/guy/miniconda3/lib/python3.8/site-packages (from requests->forex-python) (2020.6.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

from forex_python.converter import CurrencyRates
from datetime import datetime

# %% [markdown]
# Let's get the data
#
# In that case, the function here is given by the provider of this API, and for more methods, you can go to [forext-python usage page](https://forex-python.readthedocs.io/en/latest/usage.html)

# %%
usd_rates = (
    CurrencyRates()
    .get_rates('USD')
)
usd_rates
# Out:
# {'GBP': 0.7247522299,
#  'HKD': 7.7525602907,
#  'IDR': 13987.7518995705,
#  'ILS': 3.2521473406,
#  'DKK': 6.1414767096,
#  'INR': 72.5776346217,
#  'CHF': 0.8922200198,
#  'MXN': 20.0293194582,
#  'CZK': 21.2694086554,
#  'SGD': 1.3268913115,
#  'THB': 29.9099768748,
#  'HRK': 6.2528906508,
#  'EUR': 0.8259002313,
#  'MYR': 4.0425338619,
#  'NOK': 8.4943838784,
#  'CNY': 6.4591179386,
#  'BGN': 1.6152956723,
#  'PHP': 48.0517013545,
#  'PLN': 3.7164684506,
#  'ZAR': 14.6483316815,
#  'CAD': 1.2733729765,
#  'ISK': 128.6752560291,
#  'BRL': 5.3932936901,
#  'RON': 4.0259332673,
#  'NZD': 1.3908159894,
#  'TRY': 7.0209778659,
#  'JPY': 105.0132144037,
#  'RUB': 74.1703832177,
#  'KRW': 1105.0379914106,
#  'USD': 1.0,
#  'AUD': 1.2938553023,
#  'HUF': 296.3908159894,
#  'SEK': 8.3265609514}

# %% [markdown]
# Let's turn it into something more readable and easier to manipulate, by converting its type from Dictionary to DataFrame, and give its columns proper informative names.

# %%
usd_rates_df = (
    pd
    .DataFrame
    .from_dict(usd_rates, orient='index')
    .rename(columns={0 : 'Rate'})
)
usd_rates_df
# Out:
#              Rate
# GBP      0.724752
# HKD      7.752560
# IDR  13987.751900
# ILS      3.252147
# DKK      6.141477
# INR     72.577635
# CHF      0.892220
# MXN     20.029319
# CZK     21.269409
# SGD      1.326891
# THB     29.909977
# HRK      6.252891
# EUR      0.825900
# MYR      4.042534
# NOK      8.494384
# CNY      6.459118
# BGN      1.615296
# PHP     48.051701
# PLN      3.716468
# ZAR     14.648332
# CAD      1.273373
# ISK    128.675256
# BRL      5.393294
# RON      4.025933
# NZD      1.390816
# TRY      7.020978
# JPY    105.013214
# RUB     74.170383
# KRW   1105.037991
# USD      1.000000
# AUD      1.293855
# HUF    296.390816
# SEK      8.326561

# %% [markdown]
# This looks like a useful table to have if you work with multiple currencies in your organization
#
# ### Getting rates for a specific date
#
# We will use the date functionality from the API provider.
# * Call the currency API
# * Request exchange rates
# * for USD
# * for 2020-05-23

# %%
usd_rate_on_date = (
   CurrencyRates()
    .get_rates(
        'USD',
        datetime(2020, 5, 23)
    )
)
usd_rate_on_date
# Out:
# {'GBP': 0.8213774762,
#  'HKD': 7.7559611152,
#  'IDR': 14901.9992663243,
#  'ILS': 3.527054292,
#  'DKK': 6.8395084373,
#  'INR': 75.8680300807,
#  'CHF': 0.9712949376,
#  'MXN': 22.9686353632,
#  'CZK': 24.9541452678,
#  'SGD': 1.4234225972,
#  'THB': 31.8947175348,
#  'HRK': 6.9557043287,
#  'EUR': 0.9170946442,
#  'MYR': 4.3625275128,
#  'NOK': 10.0034849596,
#  'CNY': 7.1347212032,
#  'BGN': 1.7936537051,
#  'PHP': 50.76027146,
#  'PLN': 4.1460931768,
#  'ZAR': 17.6518708731,
#  'CAD': 1.40067865,
#  'ISK': 143.3418928833,
#  'BRL': 5.581162876,
#  'RON': 4.441947909,
#  'NZD': 1.6388481291,
#  'TRY': 6.8073184153,
#  'JPY': 107.5385179751,
#  'RUB': 71.4544203962,
#  'KRW': 1241.2967718269,
#  'USD': 1.0,
#  'AUD': 1.530997799,
#  'HUF': 320.432868672,
#  'SEK': 9.663701394}

# %% [markdown]
# Now, try to use the functions showed prior in order to convert it into a dataframe.

# %%
# Enter your code here

# %% [markdown]
# And in case you wondered how to do so.

# %%
usd_rate_on_date = (
    pd
    .DataFrame
    .from_dict(usd_rate_on_date, orient='index')
    .rename(columns={0 : 'Rate'})
)
usd_rate_on_date
# Out:
#              Rate
# GBP      0.821377
# HKD      7.755961
# IDR  14901.999266
# ILS      3.527054
# DKK      6.839508
# INR     75.868030
# CHF      0.971295
# MXN     22.968635
# CZK     24.954145
# SGD      1.423423
# THB     31.894718
# HRK      6.955704
# EUR      0.917095
# MYR      4.362528
# NOK     10.003485
# CNY      7.134721
# BGN      1.793654
# PHP     50.760271
# PLN      4.146093
# ZAR     17.651871
# CAD      1.400679
# ISK    143.341893
# BRL      5.581163
# RON      4.441948
# NZD      1.638848
# TRY      6.807318
# JPY    107.538518
# RUB     71.454420
# KRW   1241.296772
# USD      1.000000
# AUD      1.530998
# HUF    320.432869
# SEK      9.663701

# %% [markdown]
# ### Putting it all together
#
# * Create a Dataframe
# * From dictionary
# * Taken from the currency rate API
# * for USD
# * based on string date of 2020-05-23
# * as a single column
# * rename the column to Rate

# %%
usd_rate_on_date = (
    pd
    .DataFrame
    .from_dict(
        CurrencyRates()
            .get_rates(
                'USD',
                datetime.strptime('2020-05-23', '%Y-%m-%d')
        ),
        orient='index')
    .rename(columns={0 : 'Rate'})
)
usd_rate_on_date
# Out:
#              Rate
# GBP      0.821377
# HKD      7.755961
# IDR  14901.999266
# ILS      3.527054
# DKK      6.839508
# INR     75.868030
# CHF      0.971295
# MXN     22.968635
# CZK     24.954145
# SGD      1.423423
# THB     31.894718
# HRK      6.955704
# EUR      0.917095
# MYR      4.362528
# NOK     10.003485
# CNY      7.134721
# BGN      1.793654
# PHP     50.760271
# PLN      4.146093
# ZAR     17.651871
# CAD      1.400679
# ISK    143.341893
# BRL      5.581163
# RON      4.441948
# NZD      1.638848
# TRY      6.807318
# JPY    107.538518
# RUB     71.454420
# KRW   1241.296772
# USD      1.000000
# AUD      1.530998
# HUF    320.432869
# SEK      9.663701

# %% [markdown]
# ## Deal conversion
#
# Now, let's create a calculator that get's the amount of money we got/payed and in which currency
#
# * Call the API
# * For conversion rate
# * from USD
# * to EUR
# * of $100
# * on 2020-05-23

# %%
( 
    CurrencyRates()
    .convert(
            'USD',
            'EUR',
             100,
            datetime.strptime('2020-05-23', '%Y-%m-%d')
        )
)
# Out:
# 91.70946442

# %% [markdown]
# Now this data is useful while trying to calculate all sort of financial related data.

# %% [markdown]
# ### Additional rates sources
#
# And for cases when the wanted currency is not available through the API, there is always the option of scrapping it.
#
# Here is example of scrapping ILS rate to USD from one of the popular financial websites in Israel.
# * Create dataframes from HTML tables in the newspaper currency website
# * Take the first table (index 0)
# * Take the value in cell 1,1

# %%
(
    pd
    .read_html('https://www.globes.co.il/portal/instrument.aspx?instrumentid=10463')
    [0]
    .iloc[1,1]
)
# Out:
# '3.249'

# %% [markdown]
# In this example we have scrapped the currency rate from a non-API based website for our use.<br>
# As for this example, this technique is relevent for many optional analysis.

# %% [markdown]
# ## Analysis Use-case
#
# Now, use case to show how useful descion based data regarding currency could be.
#
# In order to show that, we will scrap a dataframe of the rates of the ILS-USD for the last almost full year.

# %%
df = (
    pd
    .read_html('https://www.exchange-rates.org/history/ILS/USD/T')
    [0]
    .rename(columns = {0 : 'Date', 1: 'Day', 2 : 'Rate', 3 : 'Notes'})
    .assign(Rate = lambda x : x.Rate.str.replace('[^\d\.]','',regex=True).astype(float))
)
df
# Out:
#           Date        Day     Rate                       Notes
# 0    2/12/2021     Friday  3.25087  USD ILS rate for 2/12/2021
# 1    2/11/2021   Thursday  3.24945  USD ILS rate for 2/11/2021
# 2    2/10/2021  Wednesday  3.25610  USD ILS rate for 2/10/2021
# 3     2/9/2021    Tuesday  3.24405   USD ILS rate for 2/9/2021
# 4     2/8/2021     Monday  3.26565   USD ILS rate for 2/8/2021
# ..         ...        ...      ...                         ...
# 132  8/20/2020   Thursday  3.39621  USD ILS rate for 8/20/2020
# 133  8/19/2020  Wednesday  3.41787  USD ILS rate for 8/19/2020
# 134  8/18/2020    Tuesday  3.39666  USD ILS rate for 8/18/2020
# 135  8/17/2020     Monday  3.40525  USD ILS rate for 8/17/2020
# 136  8/16/2020     Sunday  3.40256  USD ILS rate for 8/16/2020
#
# [137 rows x 4 columns]

# %% [markdown]
# Now let's check in which day of the week, does the rate of the ILS is "stronger", in accordance to the USD.<br>
# This data could be useful in order to maximize the rate when doing currency conversions on a regular basis.

# %% [markdown]
# Now let's try to check for the days with the highest average rate of the ILS in comparing to the USD.
#
# In order to do so, we will aggregate with Group-by, all of the values by the Day of the week, and check for the average (mean) value for each day.
#
# Beside that, let's also orgnaize our data by some order, in order case descending.

# %%
(
    df
    .groupby(['Day'])
    ['Rate']
    .mean()
    .sort_values(ascending=False)
)
# Out:
# Day
# Sunday       3.410187
# Monday       3.335234
# Friday       3.330482
# Tuesday      3.329556
# Thursday     3.326494
# Wednesday    3.325985
# Name: Rate, dtype: float64

# %% [markdown]
# And the result is? Well, Sunday.<br>
#
# Our guess is that its related to the fact that Sunday is weekend in the US and therefore, trade volumes are lower.
#
# This, we assess, reduces the affect of the general trend.

# %% [markdown]
# Another test, would be to do the same, but with the median value for each week day.

# %%
(
    df
    .groupby(['Day'])
    ['Rate']
    .median()
    .sort_values(ascending=False)
)
# Out:
# Day
# Sunday       3.402560
# Tuesday      3.362655
# Wednesday    3.362030
# Monday       3.359220
# Friday       3.349445
# Thursday     3.349205
# Name: Rate, dtype: float64

# %% [markdown]
# ### Analysis output
#
# Bottom line, if you are converting ILS to USD, try doing it on Sunday. You will probably get the better rate. On the other hand, if you are trading USD to ILS, just don't do it on Sunday.
#
# One more note, did you notice how we used and scrapped many types of websites, side by our API.
#
# The reason? None of them was sufficient so we had to dig deeper. and thats OK.
#
# So, one last tip from us to you, don't be afraid of looking for your data source.

# %% [markdown]
# ## Data Visualization
#
# ### Line Chart
#
# Now, let's try to better see and and possibly explorate, the results we just recieved.

# %% [markdown]
# First, few actions needs to be done in prior.

# %%
import matplotlib.pyplot as plt

# %%
usd_to_ils_rates = (
    pd
    .read_html('https://www.exchange-rates.org/history/ILS/USD/T')
    [0]
    .rename(columns = {0 : 'Date', 1: 'Day', 2 : 'Rate', 3 : 'Notes'})
    .assign(Rate = lambda x : x.Rate.str.replace('[^\d\.]','',regex=True).astype(float))
    .assign(Date = lambda x : pd.to_datetime(x.Date))
    .set_index('Date')
)
usd_to_ils_rates
# Out:
#                   Day     Rate                       Notes
# Date
# 2021-02-12     Friday  3.25087  USD ILS rate for 2/12/2021
# 2021-02-11   Thursday  3.24945  USD ILS rate for 2/11/2021
# 2021-02-10  Wednesday  3.25610  USD ILS rate for 2/10/2021
# 2021-02-09    Tuesday  3.24405   USD ILS rate for 2/9/2021
# 2021-02-08     Monday  3.26565   USD ILS rate for 2/8/2021
# ...               ...      ...                         ...
# 2020-08-20   Thursday  3.39621  USD ILS rate for 8/20/2020
# 2020-08-19  Wednesday  3.41787  USD ILS rate for 8/19/2020
# 2020-08-18    Tuesday  3.39666  USD ILS rate for 8/18/2020
# 2020-08-17     Monday  3.40525  USD ILS rate for 8/17/2020
# 2020-08-16     Sunday  3.40256  USD ILS rate for 8/16/2020
#
# [137 rows x 3 columns]

# %%
(
    usd_to_ils_rates
    ['Rate']
    .plot(title='Exchange Rates: USD-ILS')
);

# %% [markdown]
# ### Scatter Plot
#
# Now let's try something else, to demonstrate the differences between the days.

# %%
(
    usd_to_ils_rates
    .plot
    .scatter(
        x='Day',
        y='Rate',
        c='Red',
        title='Exchange Rates: USD-ILS across the week days'
    )
);

# %% [markdown]
# Something here looks odd. it appears there are less trading 'Sundays', which could be the reason for our former result.<br>
# Let's check it.

# %%
(
    usd_to_ils_rates
    .groupby('Day')
    ['Rate']
    .count()
)
# Out:
# Day
# Friday       26
# Monday       26
# Sunday        7
# Thursday     26
# Tuesday      26
# Wednesday    26
# Name: Rate, dtype: int64

# %% [markdown]
# Yep, totally true. therefore, let's check for the all the other days excluding Sunday.<br>
# Filtering the Dataframe to exclude Sundays.

# %%
(
    usd_to_ils_rates
    .query('Day != "Sunday"')
    .plot
    .scatter(
        x='Day',
        y='Rate',
        c='Green',
        title='Exchange Rates: USD-ILS across the working days'
    )
);

# %% [markdown]
# And based on the most lower points, we can now see that the lowest days occurs in the mid-of-the-week days.<br>

# %% [markdown]
# ## Analyze Across Weeks using Groupby
#
# Another cool way to possible be able to better identifiy the aforementioned trend, check the max & min weekly rate, and on which day did it happen.
#
# First, let's set up our data in a way that will allow us to analyze it.

# %% [markdown]
# And by a grouped table, which will show the day of each week which the highest, and later the lowest rate occured on.

# %%
(
     usd_to_ils_rates
     .assign(Week = usd_to_ils_rates.index.week)
     .groupby(['Week'])
     ['Day', 'Rate']
     .max()
     .style
     .background_gradient(cmap='summer', subset=['Rate'])
)
# Out:
# <ipython-input-20-d17f9c36cd1b>:3: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   .assign(Week = usd_to_ils_rates.index.week)
# <ipython-input-20-d17f9c36cd1b>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   usd_to_ils_rates
# <style  type="text/css" >
# #T_556075b6_6e95_11eb_ac48_acde48001122row0_col1{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row1_col1{
#             background-color:  #399c66;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row2_col1{
#             background-color:  #389c66;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row3_col1{
#             background-color:  #43a166;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row4_col1{
#             background-color:  #52a866;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row5_col1{
#             background-color:  #319866;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row6_col1{
#             background-color:  #b7db66;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row7_col1{
#             background-color:  #c6e266;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row8_col1{
#             background-color:  #bbdd66;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row9_col1{
#             background-color:  #95ca66;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row10_col1,#T_556075b6_6e95_11eb_ac48_acde48001122row13_col1{
#             background-color:  #ebf566;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row11_col1{
#             background-color:  #d5ea66;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row12_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row14_col1{
#             background-color:  #cae466;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row15_col1,#T_556075b6_6e95_11eb_ac48_acde48001122row16_col1{
#             background-color:  #aad466;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row17_col1{
#             background-color:  #c5e266;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row18_col1{
#             background-color:  #c0e066;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row19_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row20_col1{
#             background-color:  #92c866;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row21_col1{
#             background-color:  #7fbf66;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row22_col1{
#             background-color:  #61b066;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row23_col1{
#             background-color:  #2d9666;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row24_col1{
#             background-color:  #279366;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row25_col1{
#             background-color:  #1d8e66;
#             color:  #000000;
#         }#T_556075b6_6e95_11eb_ac48_acde48001122row26_col1{
#             background-color:  #168a66;
#             color:  #000000;
#         }</style><table id="T_556075b6_6e95_11eb_ac48_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Day</th>        <th class="col_heading level0 col1" >Rate</th>    </tr>    <tr>        <th class="index_name level0" >Week</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_556075b6_6e95_11eb_ac48_acde48001122level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row0_col0" class="data row0 col0" >Wednesday</td>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row0_col1" class="data row0 col1" >3.214590</td>
#             </tr>
#             <tr>
#                         <th id="T_556075b6_6e95_11eb_ac48_acde48001122level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row1_col0" class="data row1 col0" >Wednesday</td>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row1_col1" class="data row1 col1" >3.273360</td>
#             </tr>
#             <tr>
#                         <th id="T_556075b6_6e95_11eb_ac48_acde48001122level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row2_col0" class="data row2 col0" >Wednesday</td>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row2_col1" class="data row2 col1" >3.272890</td>
#             </tr>
#             <tr>
#                         <th id="T_556075b6_6e95_11eb_ac48_acde48001122level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row3_col0" class="data row3 col0" >Wednesday</td>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row3_col1" class="data row3 col1" >3.283390</td>
#             </tr>
#             <tr>
#                         <th id="T_556075b6_6e95_11eb_ac48_acde48001122level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row4_col0" class="data row4 col0" >Wednesday</td>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row4_col1" class="data row4 col1" >3.299270</td>
#             </tr>
#             <tr>
#                         <th id="T_556075b6_6e95_11eb_ac48_acde48001122level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row5_col0" class="data row5 col0" >Wednesday</td>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row5_col1" class="data row5 col1" >3.265650</td>
#             </tr>
#             <tr>
#                         <th id="T_556075b6_6e95_11eb_ac48_acde48001122level0_row6" class="row_heading level0 row6" >33</th>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row6_col0" class="data row6 col0" >Sunday</td>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row6_col1" class="data row6 col1" >3.402560</td>
#             </tr>
#             <tr>
#                         <th id="T_556075b6_6e95_11eb_ac48_acde48001122level0_row7" class="row_heading level0 row7" >34</th>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row7_col0" class="data row7 col0" >Wednesday</td>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row7_col1" class="data row7 col1" >3.417870</td>
#             </tr>
#             <tr>
#                         <th id="T_556075b6_6e95_11eb_ac48_acde48001122level0_row8" class="row_heading level0 row8" >35</th>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row8_col0" class="data row8 col0" >Wednesday</td>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row8_col1" class="data row8 col1" >3.406910</td>
#             </tr>
#             <tr>
#                         <th id="T_556075b6_6e95_11eb_ac48_acde48001122level0_row9" class="row_heading level0 row9" >36</th>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row9_col0" class="data row9 col0" >Wednesday</td>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row9_col1" class="data row9 col1" >3.367810</td>
#             </tr>
#             <tr>
#                         <th id="T_556075b6_6e95_11eb_ac48_acde48001122level0_row10" class="row_heading level0 row10" >37</th>
#                         <td id="T_556075b6_6e95_11eb_ac48_acde48001122row10_col0" class="data row10 col0" >Wednesday</td>
#                         <td id="T_556075b6_6

# %%
(
     usd_to_ils_rates
     .assign(Week = usd_to_ils_rates.index.week)
     .groupby(['Week'])
     ['Day', 'Rate']
     .min()
     .style
     .background_gradient(cmap='summer', subset=['Rate'])
)
# Out:
# <ipython-input-21-424d1ec8ea06>:3: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   .assign(Week = usd_to_ils_rates.index.week)
# <ipython-input-21-424d1ec8ea06>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   usd_to_ils_rates
# <style  type="text/css" >
# #T_5563752c_6e95_11eb_ac48_acde48001122row0_col1{
#             background-color:  #249266;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row1_col1{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row2_col1{
#             background-color:  #55aa66;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row3_col1{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row4_col1{
#             background-color:  #7fbf66;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row5_col1{
#             background-color:  #5faf66;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row6_col1{
#             background-color:  #e5f266;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row7_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row8_col1{
#             background-color:  #bfdf66;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row9_col1{
#             background-color:  #c0e066;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row10_col1{
#             background-color:  #d4ea66;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row11_col1{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row12_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row13_col1{
#             background-color:  #f5fa66;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row14_col1{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row15_col1{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row16_col1{
#             background-color:  #cbe566;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row17_col1{
#             background-color:  #ddee66;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row18_col1{
#             background-color:  #cce666;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row19_col1{
#             background-color:  #c5e266;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row20_col1{
#             background-color:  #aed666;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row21_col1{
#             background-color:  #98cc66;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row22_col1{
#             background-color:  #76bb66;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row23_col1{
#             background-color:  #63b166;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row24_col1{
#             background-color:  #56ab66;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row25_col1{
#             background-color:  #45a266;
#             color:  #000000;
#         }#T_5563752c_6e95_11eb_ac48_acde48001122row26_col1{
#             background-color:  #47a366;
#             color:  #000000;
#         }</style><table id="T_5563752c_6e95_11eb_ac48_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Day</th>        <th class="col_heading level0 col1" >Rate</th>    </tr>    <tr>        <th class="index_name level0" >Week</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5563752c_6e95_11eb_ac48_acde48001122level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row0_col0" class="data row0 col0" >Friday</td>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row0_col1" class="data row0 col1" >3.174440</td>
#             </tr>
#             <tr>
#                         <th id="T_5563752c_6e95_11eb_ac48_acde48001122level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row1_col0" class="data row1 col0" >Friday</td>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row1_col1" class="data row1 col1" >3.130680</td>
#             </tr>
#             <tr>
#                         <th id="T_5563752c_6e95_11eb_ac48_acde48001122level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row2_col0" class="data row2 col0" >Friday</td>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row2_col1" class="data row2 col1" >3.231710</td>
#             </tr>
#             <tr>
#                         <th id="T_5563752c_6e95_11eb_ac48_acde48001122level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row3_col0" class="data row3 col0" >Friday</td>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row3_col1" class="data row3 col1" >3.261980</td>
#             </tr>
#             <tr>
#                         <th id="T_5563752c_6e95_11eb_ac48_acde48001122level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row4_col0" class="data row4 col0" >Friday</td>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row4_col1" class="data row4 col1" >3.281990</td>
#             </tr>
#             <tr>
#                         <th id="T_5563752c_6e95_11eb_ac48_acde48001122level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row5_col0" class="data row5 col0" >Friday</td>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row5_col1" class="data row5 col1" >3.244050</td>
#             </tr>
#             <tr>
#                         <th id="T_5563752c_6e95_11eb_ac48_acde48001122level0_row6" class="row_heading level0 row6" >33</th>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row6_col0" class="data row6 col0" >Sunday</td>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row6_col1" class="data row6 col1" >3.402560</td>
#             </tr>
#             <tr>
#                         <th id="T_5563752c_6e95_11eb_ac48_acde48001122level0_row7" class="row_heading level0 row7" >34</th>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row7_col0" class="data row7 col0" >Friday</td>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row7_col1" class="data row7 col1" >3.395600</td>
#             </tr>
#             <tr>
#                         <th id="T_5563752c_6e95_11eb_ac48_acde48001122level0_row8" class="row_heading level0 row8" >35</th>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row8_col0" class="data row8 col0" >Friday</td>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row8_col1" class="data row8 col1" >3.358090</td>
#             </tr>
#             <tr>
#                         <th id="T_5563752c_6e95_11eb_ac48_acde48001122level0_row9" class="row_heading level0 row9" >36</th>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row9_col0" class="data row9 col0" >Friday</td>
#                         <td id="T_5563752c_6e95_11eb_ac48_acde48001122row9_col1" class="data row9 col1" >3.358820</td>
#             </tr>
#             <tr>
#                         <th id="T_5563752c_6e95_11eb_ac48_acde48001122level0_row10" class="row_heading level0 row10" >37</th>
#                         <td id="T_5

# %% [markdown]
# ### Analysis conclusion
#
# And here is the answer for our question - which days are the best day to conduct a currency conversion between USD and ILS to maximize your profits: Wednsday for USD to ILS and Friday to ILS to USD
