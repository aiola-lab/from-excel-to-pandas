# %% [markdown]
# # Currency Rate Analysis

# %% [markdown]
# > Money often costs too much. --Ralph Waldo Emerson
#
# A very used expression in our life, and if utilized just right, also very useful.
#
# In this notebook, we query a REST API to get the latest currency rates for many currencies. Using dynamic API compared to loading static files allows for updated data to be processed.

# %% [markdown]
# ## Loading data using API
#
# First of all, let's get our data.
#
# In order to do so, let's start with installing all the needed libraries and get the right imports.

# %%
pip install forex-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: forex-python in /home/vscode/.local/lib/python3.9/site-packages (1.5)
# Requirement already satisfied: simplejson in /home/vscode/.local/lib/python3.9/site-packages (from forex-python) (3.17.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from forex-python) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/site-packages (from requests->forex-python) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests->forex-python) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests->forex-python) (1.26.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests->forex-python) (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

from forex_python.converter import CurrencyRates
from datetime import datetime

# %% [markdown]
# Let's get the data
#
# In that case, the function here is given by the provider of this API, and for more methods, you can go to [forext-python usage page](https://forex-python.readthedocs.io/en/latest/usage.html)

# %%
usd_rates = (
    CurrencyRates()
    .get_rates('USD')
)
usd_rates
# Out:
# {'GBP': 0.7310186729,
#  'HKD': 7.7528342781,
#  'IDR': 14037.054018006,
#  'ILS': 3.2968489496,
#  'DKK': 6.1993164388,
#  'INR': 72.8863787929,
#  'CHF': 0.9018006002,
#  'MXN': 20.2487495832,
#  'CZK': 21.5863621207,
#  'SGD': 1.335861954,
#  'THB': 30.0600200067,
#  'HRK': 6.3116872291,
#  'EUR': 0.8336112037,
#  'MYR': 4.0585195065,
#  'NOK': 8.6178726242,
#  'CNY': 6.463987996,
#  'BGN': 1.6303767923,
#  'PHP': 48.072690897,
#  'PLN': 3.7463321107,
#  'ZAR': 15.02975992,
#  'CAD': 1.2802600867,
#  'ISK': 130.126708903,
#  'BRL': 5.3588696232,
#  'RON': 4.0642714238,
#  'NZD': 1.3892964321,
#  'TRY': 7.1265421807,
#  'JPY': 105.2350783595,
#  'RUB': 75.5411803935,
#  'KRW': 1118.089363121,
#  'USD': 1.0,
#  'AUD': 1.3110203401,
#  'HUF': 296.423807936,
#  'SEK': 8.4493164388}

# %% [markdown]
# Let's turn it into something more readable and easier to manipulate, by converting its type from Dictionary to DataFrame, and give its columns proper informative names.

# %%
usd_rates_df = (
    pd
    .DataFrame
    .from_dict(usd_rates, orient='index')
    .rename(columns={0 : 'Rate'})
)
usd_rates_df
# Out:
#              Rate
# GBP      0.731019
# HKD      7.752834
# IDR  14037.054018
# ILS      3.296849
# DKK      6.199316
# INR     72.886379
# CHF      0.901801
# MXN     20.248750
# CZK     21.586362
# SGD      1.335862
# THB     30.060020
# HRK      6.311687
# EUR      0.833611
# MYR      4.058520
# NOK      8.617873
# CNY      6.463988
# BGN      1.630377
# PHP     48.072691
# PLN      3.746332
# ZAR     15.029760
# CAD      1.280260
# ISK    130.126709
# BRL      5.358870
# RON      4.064271
# NZD      1.389296
# TRY      7.126542
# JPY    105.235078
# RUB     75.541180
# KRW   1118.089363
# USD      1.000000
# AUD      1.311020
# HUF    296.423808
# SEK      8.449316

# %% [markdown]
# This looks like a useful table to have if you work with multiple currencies in your organization
#
# ### Getting rates for a specific date
#
# We will use the date functionality from the API provider.
# * Call the currency API
# * Request exchange rates
# * for USD
# * for 2020-05-23

# %%
usd_rate_on_date = (
   CurrencyRates()
    .get_rates(
        'USD',
        datetime(2020, 5, 23)
    )
)
usd_rate_on_date
# Out:
# {'GBP': 0.8213774762,
#  'HKD': 7.7559611152,
#  'IDR': 14901.9992663243,
#  'ILS': 3.527054292,
#  'DKK': 6.8395084373,
#  'INR': 75.8680300807,
#  'CHF': 0.9712949376,
#  'MXN': 22.9686353632,
#  'CZK': 24.9541452678,
#  'SGD': 1.4234225972,
#  'THB': 31.8947175348,
#  'HRK': 6.9557043287,
#  'EUR': 0.9170946442,
#  'MYR': 4.3625275128,
#  'NOK': 10.0034849596,
#  'CNY': 7.1347212032,
#  'BGN': 1.7936537051,
#  'PHP': 50.76027146,
#  'PLN': 4.1460931768,
#  'ZAR': 17.6518708731,
#  'CAD': 1.40067865,
#  'ISK': 143.3418928833,
#  'BRL': 5.581162876,
#  'RON': 4.441947909,
#  'NZD': 1.6388481291,
#  'TRY': 6.8073184153,
#  'JPY': 107.5385179751,
#  'RUB': 71.4544203962,
#  'KRW': 1241.2967718269,
#  'USD': 1.0,
#  'AUD': 1.530997799,
#  'HUF': 320.432868672,
#  'SEK': 9.663701394}

# %% [markdown]
# Now, try to use the functions showed prior in order to convert it into a dataframe.

# %%
# Enter your code here

# %% [markdown]
# And in case you wondered how to do so.

# %%
usd_rate_on_date = (
    pd
    .DataFrame
    .from_dict(usd_rate_on_date, orient='index')
    .rename(columns={0 : 'Rate'})
)
usd_rate_on_date
# Out:
#              Rate
# GBP      0.821377
# HKD      7.755961
# IDR  14901.999266
# ILS      3.527054
# DKK      6.839508
# INR     75.868030
# CHF      0.971295
# MXN     22.968635
# CZK     24.954145
# SGD      1.423423
# THB     31.894718
# HRK      6.955704
# EUR      0.917095
# MYR      4.362528
# NOK     10.003485
# CNY      7.134721
# BGN      1.793654
# PHP     50.760271
# PLN      4.146093
# ZAR     17.651871
# CAD      1.400679
# ISK    143.341893
# BRL      5.581163
# RON      4.441948
# NZD      1.638848
# TRY      6.807318
# JPY    107.538518
# RUB     71.454420
# KRW   1241.296772
# USD      1.000000
# AUD      1.530998
# HUF    320.432869
# SEK      9.663701

# %% [markdown]
# ### Putting it all together
#
# * Create a Dataframe
# * From dictionary
# * Taken from the currency rate API
# * for USD
# * based on string date of 2020-05-23
# * as a single column
# * rename the column to Rate

# %%
usd_rate_on_date = (
    pd
    .DataFrame
    .from_dict(
        CurrencyRates()
            .get_rates(
                'USD',
                datetime.strptime('2020-05-23', '%Y-%m-%d')
        ),
        orient='index')
    .rename(columns={0 : 'Rate'})
)
usd_rate_on_date
# Out:
#              Rate
# GBP      0.821377
# HKD      7.755961
# IDR  14901.999266
# ILS      3.527054
# DKK      6.839508
# INR     75.868030
# CHF      0.971295
# MXN     22.968635
# CZK     24.954145
# SGD      1.423423
# THB     31.894718
# HRK      6.955704
# EUR      0.917095
# MYR      4.362528
# NOK     10.003485
# CNY      7.134721
# BGN      1.793654
# PHP     50.760271
# PLN      4.146093
# ZAR     17.651871
# CAD      1.400679
# ISK    143.341893
# BRL      5.581163
# RON      4.441948
# NZD      1.638848
# TRY      6.807318
# JPY    107.538518
# RUB     71.454420
# KRW   1241.296772
# USD      1.000000
# AUD      1.530998
# HUF    320.432869
# SEK      9.663701

# %% [markdown]
# ## Deal conversion
#
# Now, let's create a calculator that get's the amount of money we got/payed and in which currency
#
# * Call the API
# * For conversion rate
# * from USD
# * to EUR
# * of $100
# * on 2020-05-23

# %%
( 
    CurrencyRates()
    .convert(
            'USD',
            'EUR',
             100,
            datetime.strptime('2020-05-23', '%Y-%m-%d')
        )
)
# Out:
# 91.70946442

# %% [markdown]
# Now this data is useful while trying to calculate all sort of financial related data.

# %% [markdown]
# ### Additional rates sources
#
# And for cases when the wanted currency is not available through the API, there is always the option of scrapping it.
#
# Here is example of scrapping ILS rate to USD from one of the popular financial websites in Israel.
# * Create dataframes from HTML tables in the newspaper currency website
# * Take the first table (index 0)
# * Take the value in cell 1,1

# %%
(
    pd
    .read_html('https://www.globes.co.il/portal/instrument.aspx?instrumentid=10463')
    [0]
    .iloc[1,1]
)
# Out:
# '3.298'

# %% [markdown]
# In this example we have scrapped the currency rate from a non-API based website for our use.<br>
# As for this example, this technique is relevent for many optional analysis.

# %% [markdown]
# ## Analysis Use-case
#
# Now, use case to show how useful descion based data regarding currency could be.
#
# In order to show that, we will scrap a dataframe of the rates of the ILS-USD for the last almost full year.

# %%
df = (
    pd
    .read_html('https://www.exchange-rates.org/history/ILS/USD/T')
    [0]
    .rename(columns = {0 : 'Date', 1: 'Day', 2 : 'Rate', 3 : 'Notes'})
    .assign(Rate = lambda x : x.Rate.str.replace('[^\d\.]','',regex=True).astype(float))
)
df
# Out:
#           Date        Day     Rate                       Notes
# 0     2/4/2021   Thursday  3.29547   USD ILS rate for 2/4/2021
# 1     2/3/2021  Wednesday  3.29461   USD ILS rate for 2/3/2021
# 2     2/2/2021    Tuesday  3.29465   USD ILS rate for 2/2/2021
# 3     2/1/2021     Monday  3.29927   USD ILS rate for 2/1/2021
# 4    1/29/2021     Friday  3.27730  USD ILS rate for 1/29/2021
# ..         ...        ...      ...                         ...
# 132  8/13/2020   Thursday  3.40865  USD ILS rate for 8/13/2020
# 133  8/12/2020  Wednesday  3.41475  USD ILS rate for 8/12/2020
# 134  8/11/2020    Tuesday  3.41368  USD ILS rate for 8/11/2020
# 135  8/10/2020     Monday  3.41772  USD ILS rate for 8/10/2020
# 136   8/9/2020     Sunday  3.41120   USD ILS rate for 8/9/2020
#
# [137 rows x 4 columns]

# %% [markdown]
# Now let's check in which day of the week, does the rate of the ILS is "stronger", in accordance to the USD.<br>
# This data could be useful in order to maximize the rate when doing currency conversions on a regular basis.

# %% [markdown]
# Now let's try to check for the days with the highest average rate of the ILS in comparing to the USD.
#
# In order to do so, we will aggregate with Group-by, all of the values by the Day of the week, and check for the average (mean) value for each day.
#
# Beside that, let's also orgnaize our data by some order, in order case descending.

# %%
(
    df
    .groupby(['Day'])
    ['Rate']
    .mean()
    .sort_values(ascending=False)
)
# Out:
# Day
# Sunday       3.410314
# Monday       3.341083
# Friday       3.338512
# Tuesday      3.336080
# Thursday     3.332617
# Wednesday    3.332087
# Name: Rate, dtype: float64

# %% [markdown]
# And the result is? Well, Sunday.<br>
#
# Our guess is that its related to the fact that Sunday is weekend in the US and therefore, trade volumes are lower.
#
# This, we assess, reduces the affect of the general trend.

# %% [markdown]
# Another test, would be to do the same, but with the median value for each week day.

# %%
(
    df
    .groupby(['Day'])
    ['Rate']
    .median()
    .sort_values(ascending=False)
)
# Out:
# Day
# Sunday       3.406880
# Tuesday      3.374470
# Wednesday    3.367985
# Thursday     3.363110
# Monday       3.362670
# Friday       3.361320
# Name: Rate, dtype: float64

# %% [markdown]
# ### Analysis output
#
# Bottom line, if you are converting ILS to USD, try doing it on Sunday. You will probably get the better rate. On the other hand, if you are trading USD to ILS, just don't do it on Sunday.
#
# One more note, did you notice how we used and scrapped many types of websites, side by our API.
#
# The reason? None of them was sufficient so we had to dig deeper. and thats OK.
#
# So, one last tip from us to you, don't be afraid of looking for your data source.

# %% [markdown]
# ## Data Visualization
#
# ### Line Chart
#
# Now, let's try to better see and and possibly explorate, the results we just recieved.

# %% [markdown]
# First, few actions needs to be done in prior.

# %%
import matplotlib.pyplot as plt

# %%
usd_to_ils_rates = (
    pd
    .read_html('https://www.exchange-rates.org/history/ILS/USD/T')
    [0]
    .rename(columns = {0 : 'Date', 1: 'Day', 2 : 'Rate', 3 : 'Notes'})
    .assign(Rate = lambda x : x.Rate.str.replace('[^\d\.]','',regex=True).astype(float))
    .assign(Date = lambda x : pd.to_datetime(x.Date))
    .set_index('Date')
)
usd_to_ils_rates
# Out:
#                   Day     Rate                       Notes
# Date
# 2021-02-04   Thursday  3.29547   USD ILS rate for 2/4/2021
# 2021-02-03  Wednesday  3.29461   USD ILS rate for 2/3/2021
# 2021-02-02    Tuesday  3.29465   USD ILS rate for 2/2/2021
# 2021-02-01     Monday  3.29927   USD ILS rate for 2/1/2021
# 2021-01-29     Friday  3.27730  USD ILS rate for 1/29/2021
# ...               ...      ...                         ...
# 2020-08-13   Thursday  3.40865  USD ILS rate for 8/13/2020
# 2020-08-12  Wednesday  3.41475  USD ILS rate for 8/12/2020
# 2020-08-11    Tuesday  3.41368  USD ILS rate for 8/11/2020
# 2020-08-10     Monday  3.41772  USD ILS rate for 8/10/2020
# 2020-08-09     Sunday  3.41120   USD ILS rate for 8/9/2020
#
# [137 rows x 3 columns]

# %%
(
    usd_to_ils_rates
    ['Rate']
    .plot(title='Exchange Rates: USD-ILS')
);

# %% [markdown]
# ### Scatter Plot
#
# Now let's try something else, to demonstrate the differences between the days.

# %%
(
    usd_to_ils_rates
    .plot
    .scatter(
        x='Day',
        y='Rate',
        c='Red',
        title='Exchange Rates: USD-ILS across the week days'
    )
);

# %% [markdown]
# Something here looks odd. it appears there are less trading 'Sundays', which could be the reason for our former result.<br>
# Let's check it.

# %%
(
    usd_to_ils_rates
    .groupby('Day')
    ['Rate']
    .count()
)
# Out:
# Day
# Friday       25
# Monday       26
# Sunday        8
# Thursday     26
# Tuesday      26
# Wednesday    26
# Name: Rate, dtype: int64

# %% [markdown]
# Yep, totally true. therefore, let's check for the all the other days excluding Sunday.<br>
# Filtering the Dataframe to exclude Sundays.

# %%
(
    usd_to_ils_rates
    .query('Day != "Sunday"')
    .plot
    .scatter(
        x='Day',
        y='Rate',
        c='Green',
        title='Exchange Rates: USD-ILS across the working days'
    )
);

# %% [markdown]
# And based on the most lower points, we can now see that the lowest days occurs in the mid-of-the-week days.<br>

# %% [markdown]
# ## Analyze Across Weeks using Groupby
#
# Another cool way to possible be able to better identifiy the aforementioned trend, check the max & min weekly rate, and on which day did it happen.
#
# First, let's set up our data in a way that will allow us to analyze it.

# %% [markdown]
# And by a grouped table, which will show the day of each week which the highest, and later the lowest rate occured on.

# %%
(
     usd_to_ils_rates
     .assign(Week = usd_to_ils_rates.index.week)
     .groupby(['Week'])
     ['Day', 'Rate']
     .max()
     .style
     .background_gradient(cmap='summer', subset=['Rate'])
)
# Out:
# <style  type="text/css" >
# #T_e9a6e_row0_col1{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_e9a6e_row1_col1{
#             background-color:  #399c66;
#             color:  #000000;
#         }#T_e9a6e_row2_col1{
#             background-color:  #389c66;
#             color:  #000000;
#         }#T_e9a6e_row3_col1{
#             background-color:  #43a166;
#             color:  #000000;
#         }#T_e9a6e_row4_col1{
#             background-color:  #52a866;
#             color:  #000000;
#         }#T_e9a6e_row5_col1{
#             background-color:  #bfdf66;
#             color:  #000000;
#         }#T_e9a6e_row6_col1,#T_e9a6e_row7_col1{
#             background-color:  #c6e266;
#             color:  #000000;
#         }#T_e9a6e_row8_col1{
#             background-color:  #bbdd66;
#             color:  #000000;
#         }#T_e9a6e_row9_col1{
#             background-color:  #95ca66;
#             color:  #000000;
#         }#T_e9a6e_row10_col1,#T_e9a6e_row13_col1{
#             background-color:  #ebf566;
#             color:  #000000;
#         }#T_e9a6e_row11_col1{
#             background-color:  #d5ea66;
#             color:  #000000;
#         }#T_e9a6e_row12_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_e9a6e_row14_col1{
#             background-color:  #cae466;
#             color:  #000000;
#         }#T_e9a6e_row15_col1,#T_e9a6e_row16_col1{
#             background-color:  #aad466;
#             color:  #000000;
#         }#T_e9a6e_row17_col1{
#             background-color:  #c5e266;
#             color:  #000000;
#         }#T_e9a6e_row18_col1{
#             background-color:  #c0e066;
#             color:  #000000;
#         }#T_e9a6e_row19_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_e9a6e_row20_col1{
#             background-color:  #92c866;
#             color:  #000000;
#         }#T_e9a6e_row21_col1{
#             background-color:  #7fbf66;
#             color:  #000000;
#         }#T_e9a6e_row22_col1{
#             background-color:  #61b066;
#             color:  #000000;
#         }#T_e9a6e_row23_col1{
#             background-color:  #2d9666;
#             color:  #000000;
#         }#T_e9a6e_row24_col1{
#             background-color:  #279366;
#             color:  #000000;
#         }#T_e9a6e_row25_col1{
#             background-color:  #1d8e66;
#             color:  #000000;
#         }#T_e9a6e_row26_col1{
#             background-color:  #168a66;
#             color:  #000000;
#         }</style><table id="T_e9a6e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Day</th>        <th class="col_heading level0 col1" >Rate</th>    </tr>    <tr>        <th class="index_name level0" >Week</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e9a6e_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_e9a6e_row0_col0" class="data row0 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row0_col1" class="data row0 col1" >3.214590</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_e9a6e_row1_col0" class="data row1 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row1_col1" class="data row1 col1" >3.273360</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_e9a6e_row2_col0" class="data row2 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row2_col1" class="data row2 col1" >3.272890</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_e9a6e_row3_col0" class="data row3 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row3_col1" class="data row3 col1" >3.283390</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_e9a6e_row4_col0" class="data row4 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row4_col1" class="data row4 col1" >3.299270</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row5" class="row_heading level0 row5" >32</th>
#                         <td id="T_e9a6e_row5_col0" class="data row5 col0" >Sunday</td>
#                         <td id="T_e9a6e_row5_col1" class="data row5 col1" >3.411200</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row6" class="row_heading level0 row6" >33</th>
#                         <td id="T_e9a6e_row6_col0" class="data row6 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row6_col1" class="data row6 col1" >3.417720</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row7" class="row_heading level0 row7" >34</th>
#                         <td id="T_e9a6e_row7_col0" class="data row7 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row7_col1" class="data row7 col1" >3.417870</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row8" class="row_heading level0 row8" >35</th>
#                         <td id="T_e9a6e_row8_col0" class="data row8 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row8_col1" class="data row8 col1" >3.406910</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row9" class="row_heading level0 row9" >36</th>
#                         <td id="T_e9a6e_row9_col0" class="data row9 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row9_col1" class="data row9 col1" >3.367810</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row10" class="row_heading level0 row10" >37</th>
#                         <td id="T_e9a6e_row10_col0" class="data row10 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row10_col1" class="data row10 col1" >3.456460</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row11" class="row_heading level0 row11" >38</th>
#                         <td id="T_e9a6e_row11_col0" class="data row11 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row11_col1" class="data row11 col1" >3.433940</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row12" class="row_heading level0 row12" >39</th>
#                         <td id="T_e9a6e_row12_col0" class="data row12 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row12_col1" class="data row12 col1" >3.477150</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row13" class="row_heading level0 row13" >40</th>
#                         <td id="T_e9a6e_row13_col0" class="data row13 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row13_col1" class="data row13 col1" >3.456290</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row14" class="row_heading level0 row14" >41</th>
#                         <td id="T_e9a6e_row14_col0" class="data row14 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row14_col1" class="data row14 col1" >3.422490</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row15" class="row_heading level0 row15" >42</th>
#                         <td id="T_e9a6e_row15_col0" class="data row15 col0" >Wednesday</td>
#                         <td id="T_e9a6e_row15_col1" class="data row15 col1" >3.389590</td>
#             </tr>
#             <tr>
#                         <th id="T_e9a6e_level0_row16" class="row_heading level0 row16" >43</th>
#                         <td id="T_e9a6e_row16_col0" class="data row16 col0" >Wednesday</td>
#                         <td id="T_e9a6

# %%
(
     usd_to_ils_rates
     .assign(Week = usd_to_ils_rates.index.week)
     .groupby(['Week'])
     ['Day', 'Rate']
     .min()
     .style
     .background_gradient(cmap='summer', subset=['Rate'])
)
# Out:
# <style  type="text/css" >
# #T_14e24_row0_col1{
#             background-color:  #249266;
#             color:  #000000;
#         }#T_14e24_row1_col1{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_14e24_row2_col1{
#             background-color:  #55aa66;
#             color:  #000000;
#         }#T_14e24_row3_col1{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_14e24_row4_col1{
#             background-color:  #8ac466;
#             color:  #000000;
#         }#T_14e24_row5_col1{
#             background-color:  #ecf666;
#             color:  #000000;
#         }#T_14e24_row6_col1{
#             background-color:  #e5f266;
#             color:  #000000;
#         }#T_14e24_row7_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_14e24_row8_col1{
#             background-color:  #bfdf66;
#             color:  #000000;
#         }#T_14e24_row9_col1{
#             background-color:  #c0e066;
#             color:  #000000;
#         }#T_14e24_row10_col1{
#             background-color:  #d4ea66;
#             color:  #000000;
#         }#T_14e24_row11_col1{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_14e24_row12_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_14e24_row13_col1{
#             background-color:  #f5fa66;
#             color:  #000000;
#         }#T_14e24_row14_col1{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_14e24_row15_col1{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_14e24_row16_col1{
#             background-color:  #cbe566;
#             color:  #000000;
#         }#T_14e24_row17_col1{
#             background-color:  #ddee66;
#             color:  #000000;
#         }#T_14e24_row18_col1{
#             background-color:  #cce666;
#             color:  #000000;
#         }#T_14e24_row19_col1{
#             background-color:  #c5e266;
#             color:  #000000;
#         }#T_14e24_row20_col1{
#             background-color:  #aed666;
#             color:  #000000;
#         }#T_14e24_row21_col1{
#             background-color:  #98cc66;
#             color:  #000000;
#         }#T_14e24_row22_col1{
#             background-color:  #76bb66;
#             color:  #000000;
#         }#T_14e24_row23_col1{
#             background-color:  #63b166;
#             color:  #000000;
#         }#T_14e24_row24_col1{
#             background-color:  #56ab66;
#             color:  #000000;
#         }#T_14e24_row25_col1{
#             background-color:  #45a266;
#             color:  #000000;
#         }#T_14e24_row26_col1{
#             background-color:  #47a366;
#             color:  #000000;
#         }</style><table id="T_14e24_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Day</th>        <th class="col_heading level0 col1" >Rate</th>    </tr>    <tr>        <th class="index_name level0" >Week</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_14e24_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_14e24_row0_col0" class="data row0 col0" >Friday</td>
#                         <td id="T_14e24_row0_col1" class="data row0 col1" >3.174440</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_14e24_row1_col0" class="data row1 col0" >Friday</td>
#                         <td id="T_14e24_row1_col1" class="data row1 col1" >3.130680</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_14e24_row2_col0" class="data row2 col0" >Friday</td>
#                         <td id="T_14e24_row2_col1" class="data row2 col1" >3.231710</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_14e24_row3_col0" class="data row3 col0" >Friday</td>
#                         <td id="T_14e24_row3_col1" class="data row3 col1" >3.261980</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_14e24_row4_col0" class="data row4 col0" >Monday</td>
#                         <td id="T_14e24_row4_col1" class="data row4 col1" >3.294610</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row5" class="row_heading level0 row5" >32</th>
#                         <td id="T_14e24_row5_col0" class="data row5 col0" >Sunday</td>
#                         <td id="T_14e24_row5_col1" class="data row5 col1" >3.411200</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row6" class="row_heading level0 row6" >33</th>
#                         <td id="T_14e24_row6_col0" class="data row6 col0" >Friday</td>
#                         <td id="T_14e24_row6_col1" class="data row6 col1" >3.402560</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row7" class="row_heading level0 row7" >34</th>
#                         <td id="T_14e24_row7_col0" class="data row7 col0" >Friday</td>
#                         <td id="T_14e24_row7_col1" class="data row7 col1" >3.395600</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row8" class="row_heading level0 row8" >35</th>
#                         <td id="T_14e24_row8_col0" class="data row8 col0" >Friday</td>
#                         <td id="T_14e24_row8_col1" class="data row8 col1" >3.358090</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row9" class="row_heading level0 row9" >36</th>
#                         <td id="T_14e24_row9_col0" class="data row9 col0" >Friday</td>
#                         <td id="T_14e24_row9_col1" class="data row9 col1" >3.358820</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row10" class="row_heading level0 row10" >37</th>
#                         <td id="T_14e24_row10_col0" class="data row10 col0" >Friday</td>
#                         <td id="T_14e24_row10_col1" class="data row10 col1" >3.381950</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row11" class="row_heading level0 row11" >38</th>
#                         <td id="T_14e24_row11_col0" class="data row11 col0" >Friday</td>
#                         <td id="T_14e24_row11_col1" class="data row11 col1" >3.416340</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row12" class="row_heading level0 row12" >39</th>
#                         <td id="T_14e24_row12_col0" class="data row12 col0" >Friday</td>
#                         <td id="T_14e24_row12_col1" class="data row12 col1" >3.433970</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row13" class="row_heading level0 row13" >40</th>
#                         <td id="T_14e24_row13_col0" class="data row13 col0" >Friday</td>
#                         <td id="T_14e24_row13_col1" class="data row13 col1" >3.421860</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row14" class="row_heading level0 row14" >41</th>
#                         <td id="T_14e24_row14_col0" class="data row14 col0" >Friday</td>
#                         <td id="T_14e24_row14_col1" class="data row14 col1" >3.373740</td>
#             </tr>
#             <tr>
#                         <th id="T_14e24_level0_row15" class="row_heading level0 row15" >42</th>
#                         <td id="T_14e24_row15_col0" class="data row15 col0" >Friday</td>
#                         <td id="T_14e24_row15_col1" class="data row15 col1" >3.378600</td>
#             </tr>
#             <tr>
#                         <th id="T_

# %% [markdown]
# ### Analysis conclusion
#
# And here is the answer for our question - which days are the best day to conduct a currency conversion between USD and ILS to maximize your profits: Wednsday for USD to ILS and Friday to ILS to USD
